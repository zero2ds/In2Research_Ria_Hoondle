# %%
import pandas as pd

# %%
df= pd.read_csv("projects_df.csv")

# %%
df # for viewing the data
# Out:
#      X Ticker.Symbol  Period.Ending  Accounts.Payable  Accounts.Receivable  \
# 0    0           AAL           2012      3.068000e+09        -2.220000e+08
# 1    1           AAL           2013      4.975000e+09        -9.300000e+07
# 2    2           AAL           2014      4.668000e+09        -1.600000e+08
# 3    3           AAL           2015      5.102000e+09         3.520000e+08
# 4    4           AAP           2012      2.409453e+09        -8.948200e+07
# 5    5           AAP           2013      2.609239e+09        -3.242800e+07
# 6    6           AAP           2015      3.616038e+09        -4.820900e+07
# 7    7           AAP           2016      3.757085e+09        -2.147600e+07
# 8    8          AAPL           2013      3.622300e+10        -1.949000e+09
# 9    9          AAPL           2014      4.864900e+10        -6.452000e+09
# 10  10          AAPL           2015      6.067100e+10        -3.124000e+09
# ...

# %%
pip install plotly
# Out:
# ...
#      |████████████████████████████████| 15.2 MB 126 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
px.scatter(df, x="Accounts.Payable", y="Total.Current.Assets", animation_frame="Period.Ending", animation_group="Ticker.Symbol",
           size="Cash.Ratio", color="X", hover_name="X",
           log_x=True, size_max=100, range_x=[200,500000], range_y=[2,50000000])
# Out:
# <div>                            <div id="96a3085f-5500-44b9-a1ce-8cb314ce9e28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96a3085f-5500-44b9-a1ce-8cb314ce9e28")) {                    Plotly.newPlot(                        "96a3085f-5500-44b9-a1ce-8cb314ce9e28",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Period.Ending=2012<br>Accounts.Payable=%{x}<br>Total.Current.Assets=%{y}<br>Cash.Ratio=%{marker.size}<br>X=%{marker.color}<extra></extra>","hovertext":[0.0,4.0,12.0,20.0,32.0,36.0,44.0],"ids":["AAL","AAP","ABBV","ABT","ADM","ADS","AEE"],"legendgroup":"","marker":{"color":[0,4,12,20,32,36,44],"coloraxis":"coloraxis","size":[53,23,118,114,35,28,7],"sizemode":"area","sizeref":0.0821,"symbol":"circle"},"mode":"markers","na
# ...
