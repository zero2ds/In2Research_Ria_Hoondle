# %%
import pandas as pd

# %%
df1= pd.read_csv("WHOregionLifeExpectancyAtBirth.csv")
df1
# Out:
#            Location  Period                         Indicator        Dim1  \
# 0            Africa    2019  Life expectancy at birth (years)  Both sexes
# 1            Africa    2019  Life expectancy at birth (years)        Male
# 2            Africa    2019  Life expectancy at birth (years)      Female
# 3            Africa    2015  Life expectancy at birth (years)  Both sexes
# 4            Africa    2015  Life expectancy at birth (years)        Male
# ..              ...     ...                               ...         ...
# 67  Western Pacific    2010  Life expectancy at birth (years)        Male
# 68  Western Pacific    2010  Life expectancy at birth (years)      Female
# 69  Western Pacific    2000  Life expectancy at birth (years)  Both sexes
# 70  Western Pacific    2000  Life expectancy at birth (years)        Male
# 71  Western Pacific    2000  Life expectancy at birth (years)      Female
#
#     First Tooltip
# 0           64.49
# 1           62.37
# 2           66.65
# ...

# %%
df1.columns = ['Location', 'Year', 'Issue', 'Gender', 'LifeExpectancy']
df1
# Out:
#            Location  Year                             Issue      Gender  \
# 0            Africa  2019  Life expectancy at birth (years)  Both sexes
# 1            Africa  2019  Life expectancy at birth (years)        Male
# 2            Africa  2019  Life expectancy at birth (years)      Female
# 3            Africa  2015  Life expectancy at birth (years)  Both sexes
# 4            Africa  2015  Life expectancy at birth (years)        Male
# ..              ...   ...                               ...         ...
# 67  Western Pacific  2010  Life expectancy at birth (years)        Male
# 68  Western Pacific  2010  Life expectancy at birth (years)      Female
# 69  Western Pacific  2000  Life expectancy at birth (years)  Both sexes
# 70  Western Pacific  2000  Life expectancy at birth (years)        Male
# 71  Western Pacific  2000  Life expectancy at birth (years)      Female
#
#     LifeExpectancy
# 0            64.49
# 1            62.37
# 2            66.65
# 3            62.56
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit

# %%
year=df1['Year']

# %%
y = df1[df1['Gender']=='Female']

# %%
x = df1[df1['Gender']=='Male']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df1
sns.lmplot( x="Year", y="LifeExpectancy", data=df1, fit_reg=False, hue='Gender', legend=False, markers=["o", "x", "1"],palette="Set2")
plt.legend(loc='lower right')

# %%
sns.lmplot( x="Location", y="LifeExpectancy", data=df1, fit_reg=False, hue='Gender', legend=False, markers=["o", "x", "1"],palette="Set2")
plt.legend(loc='lower right')

# %%
data= pd.read_csv("correlation_data.csv")
data
# Out:
#                      Location  basic_sanitation_available  \
# 0                 Afghanistan                        2.78
# 1                     Albania                       12.16
# 2                   Argentina                       40.01
# 3                   Australia                       35.67
# 4                     Austria                       51.23
# ..                        ...                         ...
# 101  United States of America                       25.88
# 102                   Uruguay                       39.56
# 103                   Vanuatu                        1.65
# 104                  Viet Nam                        8.28
# 105                  Zimbabwe                        1.79
#
#      cancer_diagnosis_probability_from_30_70  road_traffic_deaths  \
# 0                                       29.8                 15.1
# 1                                       17.0                 13.6
# 2                                       15.8                 14.0
# ...

# %%
del data['Location']
data
# Out:
#      basic_sanitation_available  cancer_diagnosis_probability_from_30_70  \
# 0                          2.78                                     29.8
# 1                         12.16                                     17.0
# 2                         40.01                                     15.8
# 3                         35.67                                      9.1
# 4                         51.23                                     11.4
# ..                          ...                                      ...
# 101                       25.88                                     14.6
# 102                       39.56                                     16.7
# 103                        1.65                                     23.3
# 104                        8.28                                     17.1
# 105                        1.79                                     19.3
#
#      road_traffic_deaths  doctors_available_per_10000
# ...

# %%
sns.pairplot(data,  kind="reg")

# %%
data2=data.loc[1:10]

# %%
p1 = sns.heatmap(data2)
 #1=Afghanistan , 2=Albania, 3=Argentina, 4=Australia, 5=Austria, 6=Bangladesh, 7=Belgium, 8=Benin, 9=Bhutan, 10=Bolivia

# %%
df=data
df
# Out:
#      basic_sanitation_available  cancer_diagnosis_probability_from_30_70  \
# 0                          2.78                                     29.8
# 1                         12.16                                     17.0
# 2                         40.01                                     15.8
# 3                         35.67                                      9.1
# 4                         51.23                                     11.4
# ..                          ...                                      ...
# 101                       25.88                                     14.6
# 102                       39.56                                     16.7
# 103                        1.65                                     23.3
# 104                        8.28                                     17.1
# 105                        1.79                                     19.3
#
#      road_traffic_deaths  doctors_available_per_10000
# ...
